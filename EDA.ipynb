# %% [markdown]
# #Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/MentalHealthSurvey.csv')
df.head()
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science      2nd year
# 1    Male   20        UET   Postgraduate  Computer Science      3rd year
# 2    Male   20       FAST  Undergraduate  Computer Science      3rd year
# 3    Male   20        UET  Undergraduate  Computer Science      3rd year
# 4  Female   20        UET  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
# 2  2.5-3.0         Off-Campus                    No         1-3 times  ...
# 3  2.5-3.0          On-Campus                    No         No Sports  ...
# 4  3.0-3.5         Off-Campus                   Yes         No Sports  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# ...

# %% [markdown]
# 1.KNOWING ABOUT FEATURE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    87 non-null     object
#  1   age                       87 non-null     int64
#  2   university                87 non-null     object
#  3   degree_level              87 non-null     object
#  4   degree_major              87 non-null     object
#  5   academic_year             87 non-null     object
#  6   cgpa                      87 non-null     object
#  7   residential_status        87 non-null     object
#  8   campus_discrimination     87 non-null     object
#  9   sports_engagement         87 non-null     object
#  10  average_sleep             87 non-null     object
#  11  study_satisfaction        87 non-null     int64
#  12  academic_workload         87 non-null     int64
#  13  academic_pressure         87 non-null     int64
# ...

# %% [markdown]
# #univariate analysis for GENDER COLUMN

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      63
# Female    24
# Name: count, dtype: int64

# %% [markdown]
# ** we take gender column as categorical type **

# %%
df["gender"].value_counts().plot(kind="pie",autopct="%0.f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *conclusion- male is more in survey population *

# %%
df['gender'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='gender'>

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Univariate analysis for age column

# %%
df['age']
# Out:
# 0     20
# 1     20
# 2     20
# 3     20
# 4     20
#       ..
# 82    22
# 83    22
# 84    21
# 85    22
# 86    19
# Name: age, Length: 87, dtype: int64

# %% [markdown]
# *statstical analysis**

# %%
df['age'].describe()
# Out:
# count    87.000000
# mean     19.942529
# std       1.623636
# min      17.000000
# 25%      19.000000
# 50%      20.000000
# 75%      21.000000
# max      26.000000
# Name: age, dtype: float64

# %% [markdown]
# *conclusion-75 % popuation is less then 21 year*

# %%
df['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **conclusion- somewhat normal distribution**

# %%
df['age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].skew()
# Out:
# 1.162575588807158

# %% [markdown]
# **conclusion - somewhat normal distribution and positive skewness is there **

# %%
df['age'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# **conclusion-- clearly one outlier with age 26**

# %% [markdown]
# #univariate analysis for university column

# %%
df['university'].value_counts()
# Out:
# university
# PU         56
# UET        10
# COMSATS     9
# FAST        6
# UMT         2
# NUST        1
# VU          1
# UOL         1
# KUST        1
# Name: count, dtype: int64

# %% [markdown]
# *clearly see that some university have 1 student so we can combine those university as other to reduce the category*

# %%
df['university'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='university'>

# %%
plt.figure(figsize=(15,10))
df['university'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %% [markdown]
# #univariate analysis for degree_level

# %%
df['degree_level']
# Out:
# 0     Undergraduate
# 1      Postgraduate
# 2     Undergraduate
# 3     Undergraduate
# 4     Undergraduate
#           ...
# 82    Undergraduate
# 83    Undergraduate
# 84    Undergraduate
# 85    Undergraduate
# 86    Undergraduate
# Name: degree_level, Length: 87, dtype: object

# %%
df['degree_level'].value_counts()
# Out:
# degree_level
# Undergraduate    85
# Postgraduate      2
# Name: count, dtype: int64

# %%
df['degree_level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='degree_level'>

# %%
df['degree_level'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for degree_major

# %%
df['degree_major']
# Out:
# 0               Data Science
# 1           Computer Science
# 2           Computer Science
# 3           Computer Science
# 4           Computer Science
#                ...
# 82    Information Technology
# 83      Software Engineering
# 84              Data Science
# 85              Data Science
# 86              Data Science
# Name: degree_major, Length: 87, dtype: object

# %%
df['degree_major'].value_counts()
# Out:
# degree_major
# Data Science              41
# Computer Science          34
# Information Technology     9
# Software Engineering       3
# Name: count, dtype: int64

# %%
df['degree_major'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='degree_major'>

# %%
df['degree_major'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for academic_year

# %%
df['academic_year']
# Out:
# 0     2nd year
# 1     3rd year
# 2     3rd year
# 3     3rd year
# 4     3rd year
#         ...
# 82    4th year
# 83    4th year
# 84    2nd year
# 85    2nd year
# 86    2nd year
# Name: academic_year, Length: 87, dtype: object

# %%
df['academic_year'].value_counts()
# Out:
# academic_year
# 1st year    34
# 3rd year    28
# 2nd year    15
# 4th year    10
# Name: count, dtype: int64

# %%
df['academic_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='academic_year'>

# %%
df['academic_year'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for cgpa

# %%
df['cgpa']
# Out:
# 0     3.0-3.5
# 1     3.0-3.5
# 2     2.5-3.0
# 3     2.5-3.0
# 4     3.0-3.5
#        ...
# 82    3.0-3.5
# 83    3.5-4.0
# 84    2.0-2.5
# 85    2.5-3.0
# 86    3.5-4.0
# Name: cgpa, Length: 87, dtype: object

# %%
df['cgpa'].value_counts()
# Out:
# cgpa
# 3.0-3.5    27
# 3.5-4.0    27
# 2.5-3.0    22
# 0.0-0.0     5
# 2.0-2.5     4
# 1.5-2.0     2
# Name: count, dtype: int64

# %%
df['cgpa'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cgpa'>

# %%
df['cgpa'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for residential_status

# %%
df['residential_status']
# Out:
# 0     Off-Campus
# 1     Off-Campus
# 2     Off-Campus
# 3      On-Campus
# 4     Off-Campus
#          ...
# 82     On-Campus
# 83    Off-Campus
# 84    Off-Campus
# 85    Off-Campus
# 86     On-Campus
# Name: residential_status, Length: 87, dtype: object

# %%
df['residential_status'].value_counts()
# Out:
# residential_status
# Off-Campus    65
# On-Campus     22
# Name: count, dtype: int64

# %%
df['residential_status'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='residential_status'>

# %%
df['residential_status'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science      2nd year
# 1    Male   20        UET   Postgraduate  Computer Science      3rd year
# 2    Male   20       FAST  Undergraduate  Computer Science      3rd year
# 3    Male   20        UET  Undergraduate  Computer Science      3rd year
# 4  Female   20        UET  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
# 2  2.5-3.0         Off-Campus                    No         1-3 times  ...
# 3  2.5-3.0          On-Campus                    No         No Sports  ...
# 4  3.0-3.5         Off-Campus                   Yes         No Sports  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# ...

# %% [markdown]
# #univariate analysis for campus_discrimination

# %%
df['campus_discrimination']
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4     Yes
#      ...
# 82     No
# 83    Yes
# 84     No
# 85     No
# 86     No
# Name: campus_discrimination, Length: 87, dtype: object

# %%
df['campus_discrimination'].value_counts()
# Out:
# campus_discrimination
# No     65
# Yes    22
# Name: count, dtype: int64

# %%
df['campus_discrimination'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='campus_discrimination'>

# %%
df['campus_discrimination'].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for sports_engagement

# %%
df['sports_engagement']
# Out:
# 0     No Sports
# 1     1-3 times
# 2     1-3 times
# 3     No Sports
# 4     No Sports
#         ...
# 82    No Sports
# 83    No Sports
# 84    No Sports
# 85    No Sports
# 86    4-6 times
# Name: sports_engagement, Length: 87, dtype: object

# %%
df['sports_engagement'].value_counts()
# Out:
# sports_engagement
# No Sports    42
# 1-3 times    24
# 4-6 times    11
# 7+ times     10
# Name: count, dtype: int64

# %%
df['sports_engagement'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sports_engagement'>

# %%
df['sports_engagement'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for average_sleep

# %%
df['average_sleep']
# Out:
# 0     4-6 hrs
# 1     4-6 hrs
# 2     2-4 hrs
# 3     4-6 hrs
# 4     4-6 hrs
#        ...
# 82    7-8 hrs
# 83    2-4 hrs
# 84    4-6 hrs
# 85    4-6 hrs
# 86    4-6 hrs
# Name: average_sleep, Length: 87, dtype: object

# %%
df['average_sleep'].value_counts()
# Out:
# average_sleep
# 4-6 hrs    50
# 7-8 hrs    32
# 2-4 hrs     5
# Name: count, dtype: int64

# %%
df['average_sleep'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='average_sleep'>

# %%
df['average_sleep'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for study_satisfaction

# %%
df['study_satisfaction']
# Out:
# 0     5
# 1     5
# 2     5
# 3     3
# 4     3
#      ..
# 82    4
# 83    5
# 84    5
# 85    3
# 86    4
# Name: study_satisfaction, Length: 87, dtype: int64

# %%
df['study_satisfaction'].value_counts()
# Out:
# study_satisfaction
# 5    32
# 4    26
# 3    23
# 1     3
# 2     3
# Name: count, dtype: int64

# %%
df['study_satisfaction'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='study_satisfaction'>

# %%
df['study_satisfaction'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science      2nd year
# 1    Male   20        UET   Postgraduate  Computer Science      3rd year
# 2    Male   20       FAST  Undergraduate  Computer Science      3rd year
# 3    Male   20        UET  Undergraduate  Computer Science      3rd year
# 4  Female   20        UET  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
# 2  2.5-3.0         Off-Campus                    No         1-3 times  ...
# 3  2.5-3.0          On-Campus                    No         No Sports  ...
# 4  3.0-3.5         Off-Campus                   Yes         No Sports  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# ...

# %% [markdown]
# #univariate analysis for academic_workload

# %%
df['academic_pressure']
# Out:
# 0     5
# 1     4
# 2     5
# 3     4
# 4     5
#      ..
# 82    1
# 83    5
# 84    2
# 85    3
# 86    4
# Name: academic_pressure, Length: 87, dtype: int64

# %%
df['academic_pressure'].value_counts()
# Out:
# academic_pressure
# 4    32
# 5    26
# 3    18
# 2     6
# 1     5
# Name: count, dtype: int64

# %%
df['academic_pressure'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='academic_pressure'>

# %%
df['academic_pressure'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univarite analysis for academic_workload

# %%
df['financial_concerns']
# Out:
# 0     4
# 1     1
# 2     3
# 3     4
# 4     2
#      ..
# 82    4
# 83    5
# 84    4
# 85    3
# 86    3
# Name: financial_concerns, Length: 87, dtype: int64

# %%
df['financial_concerns'].value_counts()
# Out:
# financial_concerns
# 5    26
# 3    22
# 4    17
# 1    13
# 2     9
# Name: count, dtype: int64

# %%
df['financial_concerns'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='financial_concerns'>

# %%
df['financial_concerns'].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univeriate analysis for social_relationships

# %%
df["social_relationships"]
# Out:
# 0     3
# 1     3
# 2     4
# 3     1
# 4     3
#      ..
# 82    4
# 83    1
# 84    3
# 85    2
# 86    4
# Name: social_relationships, Length: 87, dtype: int64

# %%
df["social_relationships"].value_counts()
# Out:
# social_relationships
# 3    33
# 4    17
# 1    17
# 2    14
# 5     6
# Name: count, dtype: int64

# %%
df["social_relationships"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='social_relationships'>

# %%
df["social_relationships"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univeriate analysis for depression

# %%
df['depression']
# Out:
# 0     2
# 1     3
# 2     2
# 3     5
# 4     5
#      ..
# 82    2
# 83    5
# 84    1
# 85    3
# 86    2
# Name: depression, Length: 87, dtype: int64

# %%
df['depression'].value_counts()
# Out:
# depression
# 3    21
# 5    20
# 4    19
# 2    14
# 1    13
# Name: count, dtype: int64

# %%
df['depression'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='depression'>

# %%
df['depression'].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univeriate analysis for anxiety

# %%
df['anxiety']
# Out:
# 0     1
# 1     3
# 2     3
# 3     5
# 4     5
#      ..
# 82    3
# 83    5
# 84    2
# 85    4
# 86    2
# Name: anxiety, Length: 87, dtype: int64

# %%
df['anxiety'].value_counts()
# Out:
# anxiety
# 4    23
# 3    19
# 2    18
# 5    17
# 1    10
# Name: count, dtype: int64

# %%
df['anxiety'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='anxiety'>

# %%
df['anxiety'].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univeriate analysis for isolation

# %%
df['isolation']
# Out:
# 0     1
# 1     3
# 2     3
# 3     5
# 4     4
#      ..
# 82    1
# 83    5
# 84    1
# 85    4
# 86    1
# Name: isolation, Length: 87, dtype: int64

# %%
df['isolation'].value_counts()
# Out:
# isolation
# 5    22
# 3    20
# 4    18
# 1    14
# 2    13
# Name: count, dtype: int64

# %%
df['isolation'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='isolation'>

# %%
df['isolation'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univariate analysis for future_insecurity

# %%
df['future_insecurity']
# Out:
# 0     2
# 1     4
# 2     1
# 3     3
# 4     4
#      ..
# 82    2
# 83    5
# 84    1
# 85    5
# 86    3
# Name: future_insecurity, Length: 87, dtype: int64

# %%
df["future_insecurity"].value_counts()
# Out:
# future_insecurity
# 3    21
# 2    17
# 5    17
# 4    16
# 1    16
# Name: count, dtype: int64

# %%
df["future_insecurity"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='future_insecurity'>

# %%
df["future_insecurity"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #univeriate analysis for stress_relief_activities

# %%
df['stress_relief_activities']
# Out:
# 0     Religious Activities, Social Connections, Onli...
# 1                                  Online Entertainment
# 2     Religious Activities, Sports and Fitness, Onli...
# 3                                  Online Entertainment
# 4                                  Online Entertainment
#                             ...
# 82      Online Entertainment, Outdoor Activities, Sleep
# 83                          Religious Activities, Sleep
# 84    Religious Activities, Sports and Fitness, Soci...
# 85                                                Sleep
# 86                                   Sports and Fitness
# Name: stress_relief_activities, Length: 87, dtype: object

# %%
a=[]
df['stress_relief_activities'].iloc[1].split(sep=",")
for i in range(0,87):
  a.extend(df['stress_relief_activities'].iloc[i].split(sep=","))

df["activity"]=pd.DataFrame(a)
df["activity"]
# Out:
# 0      Religious Activities
# 1        Social Connections
# 2      Online Entertainment
# 3      Online Entertainment
# 4      Religious Activities
#               ...
# 82     Online Entertainment
# 83     Online Entertainment
# 84     Online Entertainment
# 85     Religious Activities
# 86     Online Entertainment
# Name: activity, Length: 87, dtype: object

# %% [markdown]
# *we make our own column from last coumn itself *

# %%
df["activity"]
# Out:
# 0      Religious Activities
# 1        Social Connections
# 2      Online Entertainment
# 3      Online Entertainment
# 4      Religious Activities
#               ...
# 82     Online Entertainment
# 83     Online Entertainment
# 84     Online Entertainment
# 85     Religious Activities
# 86     Online Entertainment
# Name: activity, Length: 87, dtype: object

# %%
df["activity"].value_counts()
# Out:
# activity
# Religious Activities     25
#  Online Entertainment    16
#  Social Connections      12
# Online Entertainment      7
#  Outdoor Activities       7
#  Sports and Fitness       4
# Social Connections        3
# Sports and Fitness        3
#  Creative Outlets         3
# Creative Outlets          3
# Sleep                     2
# Nothing                   1
# Outdoor Activities        1
# Name: count, dtype: int64

# %%
df["activity"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='activity'>

# %%
df["activity"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #2.bivariate analysis

# %%
df.head(3)
# Out:
#   gender  age university   degree_level      degree_major academic_year  \
# 0   Male   20         PU  Undergraduate      Data Science      2nd year
# 1   Male   20        UET   Postgraduate  Computer Science      3rd year
# 2   Male   20       FAST  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
# 2  2.5-3.0         Off-Campus                    No         1-3 times  ...
#
#   academic_workload   academic_pressure  financial_concerns  \
# 0                  4                  5                   4
# 1                  4                  4                   1
# 2                  5                  5                   3
#
#    social_relationships  depression  anxiety  isolation  future_insecurity  \
# ...

# %% [markdown]
# #A.Gender vs Age

# %%
sns.catplot(data=df,x='gender',y='age',kind='strip')

# %%
sns.catplot(data=df,x='gender',y='age',kind='box')

# %%
sns.catplot(data=df,x='gender',y='age',kind='violin')

# %%
sns.catplot(data=df,x='gender',y='age',kind='bar')

# %%
sns.catplot(data=df,x='gender',kind='count',hue="age")

# %%
sns.displot(data=df,x='age',kind='hist',hue='gender')

# %%
sns.displot(data=df,x='age',kind='kde',hue='gender')

# %%
df_new=pd.crosstab(df['gender'],df['age'])
df_new
# Out:
# age     17  18  19  20  21  22  23  26
# gender
# Female   2   1  12   6   2   1   0   0
# Male     1  10   8  24   8   8   2   2

# %%
sns.heatmap(df_new,cmap="viridis")
# Out:
# <Axes: xlabel='age', ylabel='gender'>

# %% [markdown]
# #2.Age vs University

# %%
plt.figure(figsize=(15,10))
sns.stripplot(data=df,x='university',y='age')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df,x='university',y='age')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.violinplot(data=df,x='university',y='age')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=df,x='university',y='age')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x='university',hue="age")
plt.show()

# %%
sns.displot(data=df,x='age',kind='hist',hue='university')

# %%
sns.displot(data=df,x='age',kind='kde',hue='university')
# Out:
# <ipython-input-186-9ee357f8403e>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(data=df,x='age',kind='kde',hue='university')

# %%
df_new=pd.crosstab(df["age"],df['university'])
df_new
# Out:
# university  COMSATS  FAST  KUST  NUST  PU  UET  UMT  UOL  VU
# age
# 17                0     0     0     0   3    0    0    0   0
# 18                0     0     0     0  11    0    0    0   0
# 19                0     0     0     1  16    2    0    1   0
# 20                6     4     0     0  11    7    2    0   0
# 21                1     2     0     0   7    0    0    0   0
# 22                1     0     0     0   6    1    0    0   1
# 23                1     0     0     0   1    0    0    0   0
# 26                0     0     1     0   1    0    0    0   0

# %%
sns.heatmap(df_new,cmap='viridis')
# Out:
# <Axes: xlabel='university', ylabel='age'>

# %% [markdown]
# #3.gender vs university

# %%
df_new=pd.crosstab(df['gender'],df['university'])
df_new
# Out:
# university  COMSATS  FAST  KUST  NUST  PU  UET  UMT  UOL  VU
# gender
# Female            1     0     0     0  18    5    0    0   0
# Male              8     6     1     1  38    5    2    1   1

# %%
sns.heatmap(df_new,cmap="viridis")
# Out:
# <Axes: xlabel='university', ylabel='gender'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x='university',hue="gender")
plt.show()

# %% [markdown]
# #4.gender vs degree_level

# %%
df_new=pd.crosstab(df['gender'],df['degree_level'])
df_new
# Out:
# degree_level  Postgraduate  Undergraduate
# gender
# Female                   0             24
# Male                     2             61

# %%
sns.heatmap(df_new,cmap="viridis")
# Out:
# <Axes: xlabel='degree_level', ylabel='gender'>

# %% [markdown]
# #5.Age vs academic_pressure

# %%
df_new=pd.crosstab(df['age'],df['academic_pressure'])
df_new
# Out:
# academic_pressure  1  2  3   4   5
# age
# 17                 0  0  0   1   2
# 18                 1  1  2   5   2
# 19                 1  1  4   9   5
# 20                 1  1  5  11  12
# 21                 0  1  3   3   3
# 22                 1  2  3   1   2
# 23                 0  0  1   1   0
# 26                 1  0  0   1   0

# %%
sns.heatmap(df_new,cmap="viridis")
# Out:
# <Axes: xlabel='academic_pressure', ylabel='age'>

# %%
sns.stripplot(data=df,x="academic_pressure",y="age")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='academic_pressure', ylabel='age'>

# %%
sns.boxplot(data=df,x="academic_pressure",y="age")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='academic_pressure', ylabel='age'>

# %%
sns.violinplot(data=df,x="academic_pressure",y="age")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.barplot(data=df,x="academic_pressure",y="age")
# Out:
# <Axes: xlabel='academic_pressure', ylabel='age'>

# %%
sns.countplot(data=df,x="academic_pressure",hue="age")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# #6.degree_major vs depression

# %%
df_new=pd.crosstab(df['degree_major'],df['depression'])
df_new
# Out:
# depression               1  2   3   4  5
# degree_major
# Computer Science         3  5   7  10  9
# Data Science            10  5  12   7  7
# Information Technology   0  4   1   2  2
# Software Engineering     0  0   1   0  2

# %%
sns.heatmap(df_new,cmap="viridis")
# Out:
# <Axes: xlabel='depression', ylabel='degree_major'>

# %% [markdown]
# #7.degree_major vs isolation

# %%
df_new=pd.crosstab(df['degree_major'],df['isolation'])
df_new
# Out:
# isolation               1  2   3  4   5
# degree_major
# Computer Science        4  4   8  8  10
# Data Science            9  7  11  8   6
# Information Technology  1  2   1  1   4
# Software Engineering    0  0   0  1   2

# %%
sns.heatmap(df_new)
# Out:
# <Axes: xlabel='isolation', ylabel='degree_major'>

# %% [markdown]
# #MULTIVARIATE ANALYSIS

# %% [markdown]
# #1.age vs academic_year vs campus descrimination vs depression vs gender

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x="academic_year",y="age",hue="gender",size="depression",style="campus_discrimination")
plt.show()
